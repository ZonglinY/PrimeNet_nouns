# %%
# load super_primitives_may_12.json
import json
with open("super_primitives_may_12.json", encoding='utf-8') as f:
    super_primitives = json.load(f)

# %%
# load primenet_may_12.json
with open("primenet_may_12.json", encoding='utf-8') as f:
    primenet = json.load(f)

# %%
# reverse data to make a new dictionary that maps entities to keys;
keys = list(primenet.keys())
reverse_data = {}
for key in keys:
    for value in primenet[key]:
        if value in reverse_data:
            reverse_data[value].append(key)
        else:
            reverse_data[value] = [key]

# %%
super_primitives
# Out:
# ['website',
#  'cigar',
#  'geology',
#  'similarity',
#  'mania',
#  'lingerie',
#  'homosexuality',
#  'mongolian',
#  'englishman',
#  'transaction',
#  'linux',
#  'anthropologist',
#  'lodge',
#  'organisation',
#  'hide',
#  'firefighter',
#  'verb',
#  'heating',
#  'towel',
#  'clothes',
#  'crocodile',
#  'photoautotroph',
#  'certificate',
#  'tale',
#  'sweetener',
#  'stronghold',
#  'tv',
#  'news',
#  'cigarette',
#  'vendor',
#  'croaker',
#  'bigot',
#  'repeat',
#  'takeover',
#  'paleontology',
#  'atheist',
#  'verboseness',
#  'berry',
#  'straightness',
#  'nucleon',
#  'bunch',
#  'gamete',
#  'rad',
#  'lookaround',
#  'estrogen',
#  'sword',
#  'arthritis',
#  'filter',
#  'payer',
#  'abductor',
#  'guitar',
#  'fortress',
#  'socialism',
#  'cookout',
#  'unconsciousness',
#  'elite',
#  'algebra',
#  'handcart',
#  'notation',
#  'lung',
#  'reporting',
#  'sofa',
#  'firework',
#  'sociology',
#  'treaty',
#  'weather',
#  'squad',
#  'fairy',
#  'sheath',
#  'smartphone',
#  'tax',
#  'affection',
#  'meddler',
#  'prosthesis',
#  'prose',
#  'discrimination',
#  'ratio',
#  'cognition',
#  'germanic',
#  'detergent',
#  'cook',
#  'title',
#  'longhand',
#  'wage',
#  'adverb',
#  'committee',
#  'pharmacist',
#  'rover',
#  'opportunist',
#  'artifact',
#  'bedclothes',
#  'terseness',
#  'lawsuit',
#  'destiny',
#  'correlation',
#  'bandage',
#  'illness',
#  'loudspeaker',
#  'cement',
#  'conserve',
#  'loom',
#  'overgarment',
#  'calmness',
#  'cost',
#  'typeface',
#  'staircase',
#  'dynasty',
#  'autosome',
#  'noblewoman',
#  'pigment',
#  'thief',
#  'lesson',
#  'prescriber',
#  'artery',
#  'annuity',
#  'photographer',
#  'passtime',
#  'macromolecule',
#  'manufacturing',
#  'gender',
#  'hang',
#  'sandstone',
#  'roof',
#  'saudi',
#  'utterance',
#  'projector',
#  'subculture',
#  'poodle',
#  'borne',
#  'troublemaker',
#  'sailor',
#  'armor',
#  'radar',
#  'fatness',
#  'marketplace',
#  'obstacle',
#  'punishment',
#  'exemption',
#  'butterfish',
#  'artwork',
#  'mutton',
#  'recipient',
#  'amine',
#  'scripture',
#  'camera',
#  'blight',
#  'platoon',
#  'superhero',
#  'hydrocarbon',
#  'inference',
#  'acne',
#  'warship',
#  'metabolism',
#  'telescope',
#  'trailer',
#  'egotist',
#  'hydroxide',
#  'reserve',
#  'arousal',
#  'sodium',
#  'planetquake',
#  'hill',
#  'density',
#  'moss',
#  'trespass',
#  'metalsmith',
#  'wrongdoer',
#  'handbag',
#  'bet',
#  'beggar',
#  'saw',
#  'actuality',
#  'poker',
#  'colour',
#  'extremist',
#  'incompatibility',
#  'worthiness',
#  'caliper',
#  'nomad',
#  'printing',
#  'anesthesia',
#  'microscope',
#  'hallucinogen',
#  'repute',
#  'corpse',
#  'dependent',
#  'ox',
#  'brigade',
#  'transducer',
#  'tense',
#  'railroad',
#  'babe',
#  'droppings',
#  'coefficient',
#  'determiner',
#  'algae',
#  'intruder',
#  'gunsight',
#  'slope',
#  'planet',
#  'methylhydrazine',
#  'motorcycle',
#  'network',
#  'meter',
#  'editor',
#  'breathing',
#  'telecom',
#  'theocracy',
#  'plainsong',
#  'warhead',
#  'quark',
#  'sedge',
#  'responsibility',
#  'controller',
#  'revolutionist',
#  'colorlessness',
#  'tuple',
#  'bone',
#  'deity',
#  'weekday',
#  'kingfisher',
#  'antioxidant',
#  'thinker',
#  'swine',
#  'protrusion',
#  'disparity',
#  'categorization',
#  'muslim',
#  'antibody',
#  'trajectory',
#  'flattery',
#  'disability',
#  'greek',
#  'washplant',
#  'razor',
#  'grouper',
#  'anger',
#  'peel',
#  'tradesperson',
#  'textile',
#  'industry',
#  'trope',
#  'entertainer',
#  'credential',
#  'pick',
#  'dictatorship',
#  'pervert',
#  'squirrelfish',
#  'chore',
#  'damage',
#  'compensation',
#  'dark',
#  'balloon',
#  'sunfish',
#  'mortgage',
#  'smith',
#  'canadian',
#  'emotion',
#  'trauma',
#  'equation',
#  'asymmetry',
#  'shrub',
#  'income',
#  'subspecies',
#  'leanness',
#  'boast',
#  'videotape',
#  'nobleman',
#  'jazz',
#  'noun',
#  'hernia',
#  'summer',
#  'reply',
#  'enforcement',
#  'pork',
#  'teenager',
#  'retailing',
#  'sculpture',
#  'alphavirus',
#  'spore',
#  'arab',
#  'incest',
#  'warranty',
#  'fill',
#  'healer',
#  'multigraph',
#  'brainwave',
#  'surveillance',
#  'affair',
#  'herd',
#  'banker',
#  'vertisol',
#  'automobile',
#  'degradation',
#  'spikemoss',
#  'code',
#  'earthenware',
#  'terrorism',
#  'ornament',
#  'masturbation',
#  'insanity',
#  'trimester',
#  'premise',
#  'animation',
#  'capacitor',
#  'gathering',
#  'sergeant',
#  'vertebrate',
#  'economics',
#  'spatula',
#  'infant',
#  'pathology',
#  'financials',
#  'treasurer',
#  'scissors',
#  'sandal',
#  'fiat',
#  'goods',
#  'diagnosis',
#  'pleuromutilin',
#  'cavalry',
#  'ghost',
#  'sociability',
#  'hymn',
#  'legislature',
#  'overtime',
#  'route',
#  'earther',
#  'flamingo',
#  'horseman',
#  'interruption',
#  'serviceman',
#  'result',
#  'resistor',
#  'diviner',
#  'workplace',
#  'mood',
#  'genital',
#  'transgender',
#  'calorie',
#  'sleep',
#  'disclosure',
#  'chisel',
#  'bundle',
#  'rockfish',
#  'crunchy',
#  'nightshade',
#  'fuse',
#  'oppressor',
#  'apple',
#  'battalion',
#  'playfulness',
#  'physics',
#  'clothing',
#  'benefactor',
#  'rattlesnake',
#  'blackness',
#  'farmhand',
#  'media',
#  'manure',
#  'photo']
